# %% [markdown]
# ## ECBM E6040 Homework 4 - Programming Problem

# %%
import matplotlib
import pylab
from hw4a import *
from hw4b import *
# %matplotlib inline
# Out:
# Using gpu device 0: GRID K520

# %%
param = {
        'fold': 3,
        'lr': 0.5,
        'verbose': True,
        'decay': True,
        'win': 7,
        'nhidden': 100,
        'seed': 345,
        'emb_dimension': 500,
        'nepochs': 30,
        'savemodel': False,
        'normal': True,
        'folder':'../result'}


window = [3,7]
emb_dimension_list = [50,75]
nhidden_units = [50,100]
for nhidden in nhidden_units:
    for emb_dimension in emb_dimension_list:
        for win in window:
            param['win'] = win
            param['nhidden'] = nhidden
            param['emb_dimension'] = emb_dimension
            test_rnnslu(**param)
# Out:
# verbose: True
# normal: True
# win: 3
# savemodel: False
# fold: 3
# seed: 345
# emb_dimension: 50
# nepochs: 30
# nhidden: 50
# decay: True
# lr: 0.5
# folder: ../result
# ... loading the dataset
# ... building the model
# ... training
# NEW BEST: epoch 0 valid F1 82.08 best test F1 77.77
# NEW BEST: epoch 1 valid F1 86.56 best test F1 82.39
# NEW BEST: epoch 2 valid F1 89.47 best test F1 87.48
# NEW BEST: epoch 3 valid F1 90.49 best test F1 88.63
# NEW BEST: epoch 4 valid F1 92.09 best test F1 89.55
# NEW BEST: epoch 5 valid F1 93.32 best test F1 91.8
#
#
# NEW BEST: epoch 8 valid F1 94.06 best test F1 92.18
#
# NEW BEST: epoch 10 valid F1 95.3 best test F1 92.7
#
#
#
#
#
#
# NEW BEST: epoch 17 valid F1 96.16 best test F1 93.43
#
#
#
#
# NEW BEST: epoch 22 valid F1 96.25 best test F1 92.47
#
# NEW BEST: epoch 24 valid F1 96.53 best test F1 93.55
#
#
#
#
#
# BEST RESULT: epoch 24 valid F1 96.53 best test F1 93.55 with the model ../result
# verbose: True
# normal: True
# win: 7
# ...

# %% [markdown]
# ### Problem a: Recurrent Neural Network
# #### Bullet 1: Experiment with RNNSLU

# %% [markdown]
# #### Bullet 2: Experiment with RNNSLU without normalizing word embeddings

# %%
# TODO
param = {
        'fold': 3,
        'lr': 0.5,
        'verbose': True,
        'decay': True,
        'win': 7,
        'nhidden': 100,
        'seed': 345,
        'emb_dimension': 50,
        'nepochs': 30,
        'savemodel': False,
        'normal': False,
        'folder':'../result'}


window = [3,7]
emb_dimension_list = [50,75]
nhidden_units = [50,100]
for nhidden in nhidden_units:
    for emb_dimension in emb_dimension_list:
        for win in window:
            param['win'] = win
            param['nhidden'] = nhidden
            param['emb_dimension'] = emb_dimension
            test_rnnslu(**param)
# Out:
# verbose: True
# normal: False
# win: 3
# savemodel: False
# fold: 3
# seed: 345
# emb_dimension: 50
# nepochs: 30
# nhidden: 50
# decay: True
# lr: 0.5
# folder: ../result
# ... loading the dataset
# ... building the model
# ... training
# NEW BEST: epoch 0 valid F1 82.08 best test F1 77.77
# NEW BEST: epoch 1 valid F1 86.56 best test F1 82.39
# NEW BEST: epoch 2 valid F1 89.47 best test F1 87.48
# NEW BEST: epoch 3 valid F1 90.49 best test F1 88.63
# NEW BEST: epoch 4 valid F1 92.09 best test F1 89.55
# NEW BEST: epoch 5 valid F1 93.32 best test F1 91.8
#
#
# NEW BEST: epoch 8 valid F1 94.06 best test F1 92.18
#
# NEW BEST: epoch 10 valid F1 95.3 best test F1 92.7
#
#
#
#
#
#
# NEW BEST: epoch 17 valid F1 95.78 best test F1 92.74
# NEW BEST: epoch 18 valid F1 96.15 best test F1 93.61
#
#
#
#
# NEW BEST: epoch 23 valid F1 96.82 best test F1 93.14
#
#
#
#
#
#
# BEST RESULT: epoch 23 valid F1 96.82 best test F1 93.14 with the model ../result
# verbose: True
# normal: False
# win: 7
# ...

# %% [markdown]
# #### Bullet 3: Implement RNN with two hidden layers

# %%
# TODO
# win:3,7 emb: 50,75
#nhidden will be (50,100) (50,125) (100,100) (100,125)
param = {
        'fold': 3,
        'lr': 0.5,
        'verbose': True,
        'decay': True,
        'win': 3,
        'nhidden1': 50,
        'nhidden2': 100,
        'seed': 345,
        'emb_dimension': 50,
        'nepochs': 30,
        'savemodel': False,
        'normal': False,
        'folder':'../result'}

test_rnnslu2(**param)
# Out:
# verbose: True
# normal: False
# nhidden2: 100
# win: 3
# nhidden1: 50
# savemodel: False
# fold: 3
# seed: 345
# emb_dimension: 50
# nepochs: 30
# decay: True
# lr: 0.5
# folder: ../result
# ... loading the dataset
# ... building the model
# ... training
# NEW BEST: epoch 0 valid F1 73.85 best test F1 69.01
# NEW BEST: epoch 1 valid F1 81.13 best test F1 77.11
# NEW BEST: epoch 2 valid F1 89.7 best test F1 87.58
# NEW BEST: epoch 3 valid F1 90.61 best test F1 87.69
# NEW BEST: epoch 4 valid F1 92.06 best test F1 89.53
# NEW BEST: epoch 5 valid F1 92.64 best test F1 89.97
# NEW BEST: epoch 6 valid F1 94.03 best test F1 91.82
# NEW BEST: epoch 7 valid F1 94.75 best test F1 92.85
# NEW BEST: epoch 8 valid F1 95.47 best test F1 93.26
# NEW BEST: epoch 9 valid F1 96.23 best test F1 92.72
#
# NEW BEST: epoch 11 valid F1 96.36 best test F1 93.37
# NEW BEST: epoch 12 valid F1 96.83 best test F1 93.4
#
#
#
#
#
# NEW BEST: epoch 18 valid F1 96.96 best test F1 93.62
# ...

# %%
# TODO
param = {
        'fold': 3,
        'lr': 0.5,
        'verbose': True,
        'decay': True,
        'win': 3,
        'nhidden1': 50,
        'nhidden2': 125,
        'seed': 345,
        'emb_dimension': 50,
        'nepochs': 30,
        'savemodel': False,
        'normal': False,
        'folder':'../result'}
test_rnnslu2(**param)
# Out:
# verbose: True
# normal: False
# nhidden2: 125
# win: 3
# nhidden1: 50
# savemodel: False
# fold: 3
# seed: 345
# emb_dimension: 50
# nepochs: 30
# decay: True
# lr: 0.5
# folder: ../result
# ... loading the dataset
# ... building the model
# ... training
# NEW BEST: epoch 0 valid F1 75.23 best test F1 69.25
# NEW BEST: epoch 1 valid F1 82.46 best test F1 79.82
# NEW BEST: epoch 2 valid F1 89.17 best test F1 85.62
# NEW BEST: epoch 3 valid F1 91.33 best test F1 87.63
# NEW BEST: epoch 4 valid F1 92.31 best test F1 89.11
# NEW BEST: epoch 5 valid F1 93.35 best test F1 89.1
#
# NEW BEST: epoch 7 valid F1 94.62 best test F1 91.73
# NEW BEST: epoch 8 valid F1 95.22 best test F1 92.18
# NEW BEST: epoch 9 valid F1 95.47 best test F1 91.97
# NEW BEST: epoch 10 valid F1 96.37 best test F1 92.3
#
#
#
#
# NEW BEST: epoch 15 valid F1 96.81 best test F1 92.74
#
# NEW BEST: epoch 17 valid F1 96.95 best test F1 93.28
#
#
# NEW BEST: epoch 20 valid F1 97.04 best test F1 93.02
# ...

# %%
param = {
        'fold': 3,
        'lr': 0.5,
        'verbose': True,
        'decay': True,
        'win': 3,
        'nhidden1': 100,
        'nhidden2': 100,
        'seed': 345,
        'emb_dimension': 50,
        'nepochs': 30,
        'savemodel': False,
        'normal': False,
        'folder':'../result'}
test_rnnslu2(**param)

param = {
        'fold': 3,
        'lr': 0.5,
        'verbose': True,
        'decay': True,
        'win': 3,
        'nhidden1': 100,
        'nhidden2': 125,
        'seed': 345,
        'emb_dimension': 50,
        'nepochs': 30,
        'savemodel': False,
        'normal': False,
        'folder':'../result'}
test_rnnslu2(**param)
# Out:
# verbose: True
# normal: False
# nhidden2: 100
# win: 3
# nhidden1: 100
# savemodel: False
# fold: 3
# seed: 345
# emb_dimension: 50
# nepochs: 30
# decay: True
# lr: 0.5
# folder: ../result
# ... loading the dataset
# ... building the model
# ... training
# NEW BEST: epoch 0 valid F1 77.54 best test F1 72.23
# NEW BEST: epoch 1 valid F1 83.39 best test F1 80.16
# NEW BEST: epoch 2 valid F1 91.0 best test F1 87.63
# NEW BEST: epoch 3 valid F1 91.93 best test F1 88.94
#
# NEW BEST: epoch 5 valid F1 94.0 best test F1 90.26
# NEW BEST: epoch 6 valid F1 94.99 best test F1 92.44
# NEW BEST: epoch 7 valid F1 95.46 best test F1 91.95
# NEW BEST: epoch 8 valid F1 95.75 best test F1 93.05
# NEW BEST: epoch 9 valid F1 96.35 best test F1 92.72
# NEW BEST: epoch 10 valid F1 96.71 best test F1 93.18
#
#
#
#
# NEW BEST: epoch 15 valid F1 96.78 best test F1 93.46
# NEW BEST: epoch 16 valid F1 96.9 best test F1 92.8
# NEW BEST: epoch 17 valid F1 97.14 best test F1 93.45
# ...

# %%
param = {
        'fold': 3,
        'lr': 0.5,
        'verbose': True,
        'decay': True,
        'win': 3,
        'nhidden1': 50,
        'nhidden2': 100,
        'seed': 345,
        'emb_dimension': 75,
        'nepochs': 30,
        'savemodel': False,
        'normal': False,
        'folder':'../result'}
test_rnnslu2(**param)

param = {
        'fold': 3,
        'lr': 0.5,
        'verbose': True,
        'decay': True,
        'win': 3,
        'nhidden1': 50,
        'nhidden2': 125,
        'seed': 345,
        'emb_dimension': 75,
        'nepochs': 30,
        'savemodel': False,
        'normal': False,
        'folder':'../result'}
test_rnnslu2(**param)
# Out:
# verbose: True
# normal: False
# nhidden2: 100
# win: 3
# nhidden1: 50
# savemodel: False
# fold: 3
# seed: 345
# emb_dimension: 75
# nepochs: 30
# decay: True
# lr: 0.5
# folder: ../result
# ... loading the dataset
# ... building the model
# ... training
# NEW BEST: epoch 0 valid F1 77.81 best test F1 73.47
# NEW BEST: epoch 1 valid F1 82.06 best test F1 79.06
# NEW BEST: epoch 2 valid F1 89.66 best test F1 87.23
# NEW BEST: epoch 3 valid F1 91.76 best test F1 88.61
# NEW BEST: epoch 4 valid F1 92.19 best test F1 89.78
# NEW BEST: epoch 5 valid F1 93.42 best test F1 90.85
#
# NEW BEST: epoch 7 valid F1 95.23 best test F1 92.72
# NEW BEST: epoch 8 valid F1 96.07 best test F1 93.32
# NEW BEST: epoch 9 valid F1 96.22 best test F1 92.96
#
# NEW BEST: epoch 11 valid F1 96.52 best test F1 93.24
# NEW BEST: epoch 12 valid F1 96.63 best test F1 93.92
# NEW BEST: epoch 13 valid F1 96.66 best test F1 93.1
#
# NEW BEST: epoch 15 valid F1 96.99 best test F1 93.65
#
# ...

# %%
param = {
        'fold': 3,
        'lr': 0.5,
        'verbose': True,
        'decay': True,
        'win': 3,
        'nhidden1': 100,
        'nhidden2': 100,
        'seed': 345,
        'emb_dimension': 75,
        'nepochs': 30,
        'savemodel': False,
        'normal': True,
        'folder':'../result'}
test_rnnslu2(**param)

param = {
        'fold': 3,
        'lr': 0.5,
        'verbose': True,
        'decay': True,
        'win': 3,
        'nhidden1': 100,
        'nhidden2': 125,
        'seed': 345,
        'emb_dimension': 75,
        'nepochs': 30,
        'savemodel': False,
        'normal': True,
        'folder':'../result'}
test_rnnslu2(**param)

param = {
        'fold': 3,
        'lr': 0.5,
        'verbose': True,
        'decay': True,
        'win': 7,
        'nhidden1': 50,
        'nhidden2': 100,
        'seed': 345,
        'emb_dimension': 50,
        'nepochs': 30,
        'savemodel': False,
        'normal': True,
        'folder':'../result'}

test_rnnslu2(**param)

param = {
        'fold': 3,
        'lr': 0.5,
        'verbose': True,
        'decay': True,
        'win': 7,
        'nhidden1': 50,
        'nhidden2': 125,
        'seed': 345,
        'emb_dimension': 50,
        'nepochs': 30,
        'savemodel': False,
        'normal': True,
        'folder':'../result'}

test_rnnslu2(**param)
# Out:
# verbose: True
# normal: True
# nhidden2: 100
# win: 3
# nhidden1: 100
# savemodel: False
# fold: 3
# seed: 345
# emb_dimension: 75
# nepochs: 30
# decay: True
# lr: 0.5
# folder: ../result
# ... loading the dataset
# ... building the model
# ... training
# NEW BEST: epoch 0 valid F1 77.26 best test F1 71.61
# NEW BEST: epoch 1 valid F1 80.31 best test F1 78.26
# NEW BEST: epoch 2 valid F1 88.17 best test F1 85.31
# NEW BEST: epoch 3 valid F1 89.26 best test F1 86.93
# NEW BEST: epoch 4 valid F1 90.69 best test F1 87.8
# NEW BEST: epoch 5 valid F1 90.94 best test F1 87.72
#
# NEW BEST: epoch 7 valid F1 92.16 best test F1 88.9
#
# NEW BEST: epoch 9 valid F1 93.27 best test F1 90.87
#
# NEW BEST: epoch 11 valid F1 94.27 best test F1 91.63
# NEW BEST: epoch 12 valid F1 95.01 best test F1 91.86
#
#
# NEW BEST: epoch 15 valid F1 96.12 best test F1 93.14
#
#
#
#
#
#
#
#
#
# NEW BEST: epoch 25 valid F1 96.51 best test F1 93.26
#
# NEW BEST: epoch 27 valid F1 96.8 best test F1 93.82
#
#
# ...

# %%
param = {
        'fold': 3,
        'lr': 0.5,
        'verbose': True,
        'decay': True,
        'win': 7,
        'nhidden1': 100,
        'nhidden2': 100,
        'seed': 345,
        'emb_dimension': 50,
        'nepochs': 30,
        'savemodel': False,
        'normal': True,
        'folder':'../result'}
test_rnnslu2(**param)

param = {
        'fold': 3,
        'lr': 0.5,
        'verbose': True,
        'decay': True,
        'win': 7,
        'nhidden1': 100,
        'nhidden2': 125,
        'seed': 345,
        'emb_dimension': 50,
        'nepochs': 30,
        'savemodel': False,
        'normal': True,
        'folder':'../result'}
test_rnnslu2(**param)
# Out:
# verbose: True
# normal: True
# nhidden2: 100
# win: 7
# nhidden1: 100
# savemodel: False
# fold: 3
# seed: 345
# emb_dimension: 50
# nepochs: 30
# decay: True
# lr: 0.5
# folder: ../result
# ... loading the dataset
# ... building the model
# ... training
# NEW BEST: epoch 0 valid F1 76.74 best test F1 72.07
# NEW BEST: epoch 1 valid F1 83.89 best test F1 80.93
# NEW BEST: epoch 2 valid F1 87.37 best test F1 86.35
# NEW BEST: epoch 3 valid F1 89.77 best test F1 87.9
# NEW BEST: epoch 4 valid F1 90.35 best test F1 87.82
# NEW BEST: epoch 5 valid F1 91.35 best test F1 88.85
#
#
# NEW BEST: epoch 8 valid F1 93.11 best test F1 89.51
#
# NEW BEST: epoch 10 valid F1 93.86 best test F1 91.4
# NEW BEST: epoch 11 valid F1 94.14 best test F1 89.78
# NEW BEST: epoch 12 valid F1 95.5 best test F1 92.74
#
#
# NEW BEST: epoch 15 valid F1 95.85 best test F1 92.57
#
#
#
#
# NEW BEST: epoch 20 valid F1 95.88 best test F1 92.75
# NEW BEST: epoch 21 valid F1 95.95 best test F1 92.97
# ...

# %%
param = {
        'fold': 3,
        'lr': 0.5,
        'verbose': True,
        'decay': True,
        'win': 7,
        'nhidden1': 50,
        'nhidden2': 100,
        'seed': 345,
        'emb_dimension': 75,
        'nepochs': 30,
        'savemodel': False,
        'normal': True,
        'folder':'../result'}
test_rnnslu2(**param)
# Out:
# verbose: True
# normal: True
# nhidden2: 100
# win: 7
# nhidden1: 50
# savemodel: False
# fold: 3
# seed: 345
# emb_dimension: 75
# nepochs: 30
# decay: True
# lr: 0.5
# folder: ../result
# ... loading the dataset
# ... building the model
# ... training
# NEW BEST: epoch 0 valid F1 74.03 best test F1 69.72
# NEW BEST: epoch 1 valid F1 82.21 best test F1 78.44
# NEW BEST: epoch 2 valid F1 86.35 best test F1 84.7
# NEW BEST: epoch 3 valid F1 88.56 best test F1 86.04
# NEW BEST: epoch 4 valid F1 89.97 best test F1 87.56
# NEW BEST: epoch 5 valid F1 90.6 best test F1 88.53
# NEW BEST: epoch 6 valid F1 91.95 best test F1 89.21
#
# NEW BEST: epoch 8 valid F1 93.14 best test F1 91.26
# NEW BEST: epoch 9 valid F1 94.01 best test F1 91.85
# NEW BEST: epoch 10 valid F1 94.28 best test F1 91.71
#
#
#
# NEW BEST: epoch 14 valid F1 94.73 best test F1 91.47
# NEW BEST: epoch 15 valid F1 95.32 best test F1 93.36
#
#
#
#
#
#
# NEW BEST: epoch 22 valid F1 96.16 best test F1 92.53
#
#
# ...

# %%
param = {
        'fold': 3,
        'lr': 0.5,
        'verbose': True,
        'decay': True,
        'win': 7,
        'nhidden1': 50,
        'nhidden2': 125,
        'seed': 345,
        'emb_dimension': 75,
        'nepochs': 30,
        'savemodel': False,
        'normal': True,
        'folder':'../result'}
test_rnnslu2(**param)
param = {
        'fold': 3,
        'lr': 0.5,
        'verbose': True,
        'decay': True,
        'win': 7,
        'nhidden1': 100,
        'nhidden2': 100,
        'seed': 345,
        'emb_dimension': 75,
        'nepochs': 30,
        'savemodel': False,
        'normal': True,
        'folder':'../result'}
test_rnnslu2(**param)
# Out:
# verbose: True
# normal: True
# nhidden2: 125
# win: 7
# nhidden1: 50
# savemodel: False
# fold: 3
# seed: 345
# emb_dimension: 75
# nepochs: 30
# decay: True
# lr: 0.5
# folder: ../result
# ... loading the dataset
# ... building the model
# ... training
# NEW BEST: epoch 0 valid F1 75.12 best test F1 71.68
# NEW BEST: epoch 1 valid F1 83.23 best test F1 78.12
# NEW BEST: epoch 2 valid F1 88.86 best test F1 85.34
# NEW BEST: epoch 3 valid F1 90.0 best test F1 87.32
# NEW BEST: epoch 4 valid F1 92.44 best test F1 88.5
#
#
#
# NEW BEST: epoch 8 valid F1 94.18 best test F1 91.43
# NEW BEST: epoch 9 valid F1 94.89 best test F1 92.51
#
#
#
# NEW BEST: epoch 13 valid F1 94.99 best test F1 91.69
#
# NEW BEST: epoch 15 valid F1 95.45 best test F1 92.41
# NEW BEST: epoch 17 valid F1 96.17 best test F1 92.27
#
#
#
#
# NEW BEST: epoch 22 valid F1 96.2 best test F1 92.4
#
#
#
#
#
#
#
# BEST RESULT: epoch 22 valid F1 96.2 best test F1 92.4 with the model ../result
# verbose: True
# normal: True
# ...

# %%
param = {
        'fold': 3,
        'lr': 0.5,
        'verbose': True,
        'decay': True,
        'win': 7,
        'nhidden1': 100,
        'nhidden2': 125,
        'seed': 345,
        'emb_dimension': 75,
        'nepochs': 30,
        'savemodel': False,
        'normal': True,
        'folder':'../result'}
test_rnnslu2(**param)
# Out:
# verbose: True
# normal: True
# nhidden2: 125
# win: 7
# nhidden1: 100
# savemodel: False
# fold: 3
# seed: 345
# emb_dimension: 75
# nepochs: 30
# decay: True
# lr: 0.5
# folder: ../result
# ... loading the dataset
# ... building the model
# ... training
# NEW BEST: epoch 0 valid F1 77.9 best test F1 73.53
# NEW BEST: epoch 1 valid F1 83.31 best test F1 81.2
# NEW BEST: epoch 2 valid F1 88.79 best test F1 86.94
# NEW BEST: epoch 3 valid F1 90.75 best test F1 88.04
#
# NEW BEST: epoch 5 valid F1 92.08 best test F1 88.69
# NEW BEST: epoch 6 valid F1 93.68 best test F1 91.65
#
# NEW BEST: epoch 8 valid F1 94.11 best test F1 91.5
#
# NEW BEST: epoch 10 valid F1 94.31 best test F1 91.77
# NEW BEST: epoch 11 valid F1 94.57 best test F1 92.6
#
#
#
# NEW BEST: epoch 15 valid F1 96.17 best test F1 93.53
#
#
#
#
#
#
#
#
#
#
# NEW BEST: epoch 26 valid F1 96.44 best test F1 93.59
#
# NEW BEST: epoch 28 valid F1 96.52 best test F1 93.81
#
# ...

# %% [markdown]
# #### Bullet 4: Experiment with word embeddings

# %%
train_set, valid_set, test_set, dic = load_data(3)
dic['words2idx']
# Out:
# {"'d": 0,
#  "'ll": 1,
#  "'m": 2,
#  "'re": 3,
#  "'s": 4,
#  "'t": 5,
#  '72s': 6,
#  '<UNK>': 7,
#  'DIGIT': 8,
#  'DIGITDIGIT': 9,
#  'DIGITDIGITDIGIT': 10,
#  'DIGITDIGITDIGITDIGIT': 11,
#  'DIGITDIGITDIGITDIGITDIGITDIGIT': 12,
#  'a': 13,
#  'abbreviation': 14,
#  'abbreviations': 15,
#  'about': 16,
#  'ac': 17,
#  'actually': 18,
#  'after': 19,
#  'afternoon': 20,
#  'again': 21,
#  'air': 22,
#  'aircraft': 23,
#  'airfare': 24,
#  'airline': 25,
#  'airlines': 26,
#  'airplane': 27,
#  'airplanes': 28,
#  'airport': 29,
#  'airports': 30,
#  'alaska': 31,
#  'all': 32,
#  'along': 33,
#  'also': 34,
#  'am': 35,
#  'america': 36,
#  'american': 37,
#  'amount': 38,
#  'an': 39,
#  'and': 40,
#  'angeles': 41,
#  'another': 42,
#  'any': 43,
#  'anywhere': 44,
#  'ap': 45,
#  'ap57': 46,
#  'ap80': 47,
#  'approximately': 48,
#  'april': 49,
#  'are': 50,
#  'area': 51,
#  'arizona': 52,
#  'around': 53,
#  'arrange': 54,
#  'arrangements': 55,
#  'arrival': 56,
# ...

# %%
import numpy as np
embed = np.load('../result/embeddings.npy')

# %%
#print((dic['words2idx']))
#print(embed[101])
#print dic['words2idx']
#print embed[dic['words2idx']]
import scipy as sc
cos_val = {}
dicton = {}
dicton2 = {}
for key, value in dic['words2idx'].iteritems():
    dicton[key] = embed[value]
    
for index1 in dicton:
    for index2 in dicton:
        if index1 :
            key = index1 + " : " + index2
            dicton2[key] = dicton[index1] - dicton[index2]
for i1 in dicton2:
    for i2 in dicton2:
        if i1 != i2:
            dist = sc.spatial.distance.cosine(dicton2[i1] , dicton2[i2])
            if dist < 0.05:
                
                print i1 + ' and  ' i2
                cos_val = dist

# %%
# using cosine similarity from scipy. Here cosine is calculated as 1 - (u.v)/|u||v|. lower value means high
# similarity


print(sc.spatial.distance.cosine(dicton['night'] - dicton['dinner'], dicton['morning'] - dicton['breakfast']) )
print(sc.spatial.distance.cosine(dicton['san'] - dicton['diego'], dicton['san'] - dicton['francisco']) )
print(sc.spatial.distance.cosine(dicton['canada'] - dicton['canadian'], dicton['america'] - dicton['american']) )
print(sc.spatial.distance.cosine(dicton['earlier'] - dicton['earliest'], dicton['later'] - dicton['latest']) )
print(sc.spatial.distance.cosine(dicton['earlier'] - dicton['earliest'], dicton['later'] - dicton['latest']) )
print(sc.spatial.distance.cosine(dicton['arizona'] - dicton['phoenix'], dicton['colorado'] - dicton['denver']) )
# Out:
# 0.137540897441
# 0.236659261253
# 0.360654469861
# 0.350802273698
# 0.350802273698
# 0.410928334275

# %% [markdown]
# ### Problem b: Learning Parity Function
# #### Bullet 1: Shallow MLP

# %%
# TODO
test_mlp_parity(learning_rate=0.4, L1_reg=0.00, L2_reg=0.00, n_epochs=10000,
             batch_size=64, n_hidden=32, n_hiddenLayers=1,
             verbose=True,inp = 8)
# Out:
# ... building the model
# ... training
# training @ iter =  0
# epoch 1, minibatch 15/15, validation error 49.776786 %
#      epoch 1, minibatch 15/15, test error of best model 51.562500 %
# epoch 2, minibatch 15/15, validation error 54.241071 %
# epoch 3, minibatch 15/15, validation error 56.919643 %
# epoch 4, minibatch 15/15, validation error 56.026786 %
# epoch 5, minibatch 15/15, validation error 55.133929 %
# epoch 6, minibatch 15/15, validation error 54.910714 %
# training @ iter =  100
# epoch 7, minibatch 15/15, validation error 54.910714 %
# epoch 8, minibatch 15/15, validation error 55.133929 %
# epoch 9, minibatch 15/15, validation error 54.687500 %
# epoch 10, minibatch 15/15, validation error 54.464286 %
# epoch 11, minibatch 15/15, validation error 54.464286 %
# epoch 12, minibatch 15/15, validation error 54.464286 %
# epoch 13, minibatch 15/15, validation error 54.464286 %
# training @ iter =  200
# epoch 14, minibatch 15/15, validation error 54.910714 %
# ...

# %%
test_mlp_parity(learning_rate=0.9, L1_reg=0.00, L2_reg=0.00, n_epochs=10001,
             batch_size = 64, n_hidden=144, n_hiddenLayers=1,
             verbose=True,inp = 12)
# Out:
# ... building the model
# ... training
# training @ iter =  0
# epoch 1, minibatch 15/15, validation error 49.330357 %
#      epoch 1, minibatch 15/15, test error of best model 48.437500 %
# epoch 2, minibatch 15/15, validation error 48.883929 %
#      epoch 2, minibatch 15/15, test error of best model 46.875000 %
# epoch 3, minibatch 15/15, validation error 48.214286 %
#      epoch 3, minibatch 15/15, test error of best model 48.437500 %
# epoch 4, minibatch 15/15, validation error 48.437500 %
# epoch 5, minibatch 15/15, validation error 48.660714 %
# epoch 6, minibatch 15/15, validation error 48.660714 %
# training @ iter =  100
# epoch 7, minibatch 15/15, validation error 47.991071 %
#      epoch 7, minibatch 15/15, test error of best model 46.875000 %
# epoch 8, minibatch 15/15, validation error 48.660714 %
# epoch 9, minibatch 15/15, validation error 48.214286 %
# epoch 10, minibatch 15/15, validation error 48.214286 %
# epoch 11, minibatch 15/15, validation error 49.107143 %
# ...

# %% [markdown]
# #### Bullet 2: Deep MLP

# %%
test_mlp_parity(learning_rate=0.65, L1_reg=0.00, L2_reg=0.00, n_epochs=6000,
             batch_size=32, n_hidden=8, n_hiddenLayers=2,
             verbose=True, inp = 8)
# Out:
# ... building the model
# ... training
# training @ iter =  0
# epoch 1, minibatch 31/31, validation error 48.541667 %
#      epoch 1, minibatch 31/31, test error of best model 41.666667 %
# epoch 2, minibatch 31/31, validation error 48.333333 %
#      epoch 2, minibatch 31/31, test error of best model 38.541667 %
# epoch 3, minibatch 31/31, validation error 50.000000 %
# training @ iter =  100
# epoch 4, minibatch 31/31, validation error 50.416667 %
# epoch 5, minibatch 31/31, validation error 49.583333 %
# epoch 6, minibatch 31/31, validation error 49.583333 %
# training @ iter =  200
# epoch 7, minibatch 31/31, validation error 50.833333 %
# epoch 8, minibatch 31/31, validation error 50.625000 %
# epoch 9, minibatch 31/31, validation error 48.958333 %
# training @ iter =  300
# epoch 10, minibatch 31/31, validation error 50.000000 %
# epoch 11, minibatch 31/31, validation error 50.625000 %
# epoch 12, minibatch 31/31, validation error 52.083333 %
# training @ iter =  400
# ...

# %%
test_mlp_parity(learning_rate=0.71, L1_reg=0.00, L2_reg=0.00, n_epochs=10001,
             batch_size=64, n_hidden=12, n_hiddenLayers=2,
             verbose=True, inp = 12)
# Out:
# ... building the model
# ... training
# training @ iter =  0
# epoch 1, minibatch 15/15, validation error 46.651786 %
#      epoch 1, minibatch 15/15, test error of best model 51.562500 %
# epoch 2, minibatch 15/15, validation error 46.428571 %
#      epoch 2, minibatch 15/15, test error of best model 51.562500 %
# epoch 3, minibatch 15/15, validation error 47.767857 %
# epoch 4, minibatch 15/15, validation error 47.991071 %
# epoch 5, minibatch 15/15, validation error 48.437500 %
# epoch 6, minibatch 15/15, validation error 48.660714 %
# training @ iter =  100
# epoch 7, minibatch 15/15, validation error 49.330357 %
# epoch 8, minibatch 15/15, validation error 50.223214 %
# epoch 9, minibatch 15/15, validation error 49.776786 %
# epoch 10, minibatch 15/15, validation error 49.553571 %
# epoch 11, minibatch 15/15, validation error 49.107143 %
# epoch 12, minibatch 15/15, validation error 49.107143 %
# epoch 13, minibatch 15/15, validation error 48.660714 %
# training @ iter =  200
# ...

# %% [markdown]
# #### Bullet 3: RNN

# %%
test_rnn_parity(learning_rate=0.7, L1_reg=0.00, L2_reg=0.00, n_epochs=100,
             batch_size=32, n_hidden=8, n_hiddenLayers=1,parity=8,verbose = True)
# Out:
# ... building the model
# 1
# 1
# 1
# 1
# ... training
# training @ iter =  0
# epoch 1, minibatch 31/31, validation error 49.166667 %
#      epoch 1, minibatch 31/31, test error of best model 56.250000 %
# epoch 2, minibatch 31/31, validation error 49.166667 %
# epoch 3, minibatch 31/31, validation error 49.166667 %
# training @ iter =  100
# epoch 4, minibatch 31/31, validation error 49.166667 %
# epoch 5, minibatch 31/31, validation error 49.166667 %
# epoch 6, minibatch 31/31, validation error 49.166667 %
# training @ iter =  200
# epoch 7, minibatch 31/31, validation error 49.166667 %
# epoch 8, minibatch 31/31, validation error 49.166667 %
# epoch 9, minibatch 31/31, validation error 49.166667 %
# training @ iter =  300
# epoch 10, minibatch 31/31, validation error 48.958333 %
#      epoch 10, minibatch 31/31, test error of best model 55.208333 %
# epoch 11, minibatch 31/31, validation error 50.833333 %
# epoch 12, minibatch 31/31, validation error 50.833333 %
# ...

# %%
test_rnn_parity(learning_rate=0.8, L1_reg=0.00, L2_reg=0.00, n_epochs=100,
             batch_size=64, n_hidden=4, n_hiddenLayers=1,parity=8,verbose = True)
# Out:
# ... building the model
# 1
# 1
# 1
# 1
# ... training
# training @ iter =  0
# epoch 1, minibatch 15/15, validation error 53.571429 %
#      epoch 1, minibatch 15/15, test error of best model 39.062500 %
# epoch 2, minibatch 15/15, validation error 53.571429 %
# epoch 3, minibatch 15/15, validation error 53.571429 %
# epoch 4, minibatch 15/15, validation error 53.571429 %
# epoch 5, minibatch 15/15, validation error 53.571429 %
# epoch 6, minibatch 15/15, validation error 53.571429 %
# training @ iter =  100
# epoch 7, minibatch 15/15, validation error 53.571429 %
# epoch 8, minibatch 15/15, validation error 53.571429 %
# epoch 9, minibatch 15/15, validation error 53.571429 %
# epoch 10, minibatch 15/15, validation error 53.571429 %
# epoch 11, minibatch 15/15, validation error 53.571429 %
# epoch 12, minibatch 15/15, validation error 53.571429 %
# epoch 13, minibatch 15/15, validation error 53.571429 %
# training @ iter =  200
# ...
